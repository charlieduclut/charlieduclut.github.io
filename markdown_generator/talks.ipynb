# %% [markdown]
# # Talks markdown generator for academicpages
#
# Takes a TSV of talks with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `talks.py`. Run either from the `markdown_generator` folder after replacing `talks.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases, rather than Stuart's non-standard TSV format and citation style.

# %%
import pandas as pd
import os

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: title, type, url_slug, venue, date, location, talk_url, description, with a header at the top. Many of these fields can be blank, but the columns must be in the TSV.
#
# - Fields that cannot be blank: `title`, `url_slug`, `date`. All else can be blank. `type` defaults to "Talk"
# - `date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper.
#     - The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/talks/YYYY-MM-DD-[url_slug]`
#     - The combination of `url_slug` and `date` must be unique, as it will be the basis for your filenames
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !cat talks.csv
# Out:
# title;type;url_slug;venue;date;location;description
# Dynamical phase transition in assemblies of chemotactic cells;Invited Talk;inv-talk-1;DPG Spring Meeting, Focus Session on Stochastic processes in biology;2019-04-04;Regensburg Universität,  Regensburg, Germany;
# Fluid pumping and flexoelectricity can drive lumen nucleation in cell spheroids;Invited Talk;inv-talk-2;"Labex ""Who am I?"" 2022 annual meeting";2022-12-12;ENSA, Paris, France;
# Genuine (response-field) Langevin equations for reaction-diffusion processes ;Contributed talk;talk-1;Journées de Physique Statistique;2016-01-28;ESPCI, Paris, France;
# Langevin equations for reaction-diffusion processes;Contributed talk;talk-2;DPG Spring Meeting;2018-03-12;Technische Universität Berlin, Berlin, Germany;
# Frequency regulators for the nonperturbative renormalization group in nonequilibrium systems;Contributed talk;talk-3;Exact Renormalization Group (ERG2018);2018-07-10;Sorbonne Université, Paris, France;
# Fluid pumping can drive lumen nucleation and thickness oscillations in a cell spheroid;Contributed talk;talk-4;Circle Meeting;2019-03-27;Saarland Universität, Saarbrücken, Germany;
# Hydraulic and electric control of cell spheroids;Contributed talk;talk-5;Virtual APS March Meeting;2021-03-16;online conference;
# Hydraulic and electric control of cell spheroids;Contributed talk;talk-6;Virtual DPG Spring Meeting;2021-03-23;online conference;
# Nonlinear rheology of cellular networks;Contributed talk;talk-7;Physical Biology Circle Meeting;2021-09-15;Max Planck Institute for the Physics of Complex Systems, Dresden, Germany;
# Hydraulic and electric control of a cell spheroid;Contributed talk;talk-8;New frontiers in liquid matter;2022-07-07;Sorbonne Université, Paris, France;
# Nonequilibrium critical phenomena: exact Langevin equations, erosion of tilted landscapes;Seminar;seminar-1;Max Planck Institute for the Physics of Complex Systems;2017-03-30;Dresden, Germany;
# Collective dynamics of chemotactic cells;Seminar;seminar-2;Laboratoire de Physique;2020-01-07;École Normale Supérieure de Lyon, Lyon, France;
# Collective dynamics of chemotactic cells;Seminar;seminar-3;Laboratoire Interdisciplinaire de Physique;2020-01-09;Université Grenoble-Alpes, Grenoble, France;
# Collective dynamics of chemotactic cells;Seminar;seminar-4;Laboratoire Matière et Systèmes Complexes;2020-01-15;Université de Paris, Paris, France;
# Quorum effects in assemblies of chemotactic cells;Seminar;seminar-5;Laboratoire de Physique Théorique et Modèles Statistiques (online seminar);2020-03-31;Université Paris-Orsay, Orsay, France;
# Polarization mechanism for chemotaxis and exact scaling exponent in assemblies of cells;Seminar;seminar-6;Centre de Physique Théorique (online seminar);2020-10-14;Aix-Marseille Université, Marseille, France;
# Fluid pumping, lumen nucleation and electro-hydraulic phenomena in cell assemblies;Seminar;seminar-7;Laboratoire Interdisciplinaire de Physique (online seminar);2020-11-02;Université Grenoble-Alpes, Grenoble, France;
# Fluid pumping, lumen nucleation and electro-hydraulic phenomena in cell assemblies;Seminar;seminar-8;Laboratoire Jean Perrin (online seminar);2020-11-10;Sorbonne Université, Paris, France ;
# Active mechanical and electrohydraulic properties of tissues;Seminar;seminar-9;Laboratoire Matière et Systèmes Complexes;2021-12-13;Université de Paris, Paris, France;
# Active mechanical and electrohydraulic properties of tissues;Seminar;seminar-10;Laboratoire Physico-Chimie Curie;2022-01-28;Institut Curie, Paris, France;
# Active mechanical and electrohydraulic properties of tissues;Seminar;seminar-11;Laboratoire Physique et Mécanique des Milieux Hétérogènes;2022-02-16;ESPCI, Paris, France;
# Active mechanical and electrohydraulic properties of tissues;Seminar;seminar-12;Laboratoire Jean Perrin ;2022-02-22;Sorbonne Université, Paris, France ;
# Renormalization group approach to the collective dynamics of chemotactic cells;Seminar;seminar-13;Laboratoire de Physique Théorique de la Matière Condensée;2022-10-10;Sorbonne Université, Paris, France ;
# Hysteresis, phase transitions and dangerous transients in power distribution systems;Poster;poster-1;Optimization and Control of Smart Grids;2012-05-21;Santa Fe, New Mexico, USA;
# Langevin equations for reaction-diffusion processes;Poster;poster-2;Beg Rohu summer school;2016-08-01;Beg Rohu, France;
# Langevin equations for reaction-diffusion processes;Poster;poster-3;42nd Conference of the Middle European Cooperation in Statistical Physics;2017-02-09;École Normale Supérieure de Lyon, Lyon, France;
# Fluid pumping and active flexoelectricity can promote lumen nucleation in cell assemblies;Poster;poster-4;Les Houches summer school;2018-08-01;Les Houches, France;
# Fluid pumping and active flexoelectricity can promote lumen nucleation in cell assemblies;Poster;poster-5;Key Challenges in Statistical Physics (MECO 44);2019-05-01;Kloster Seeon, Munich, Germany;
# Fluid pumping and active flexoelectricity can promote lumen nucleation in cell assemblies;Poster;poster-6;Mechanical Forces in Development;2019-07-03;EMBL, Heidelberg, Germany;
# Fluid pumping and active flexoelectricity can promote lumen nucleation in cell assemblies;Poster;poster-7;Fluid Physics of Life;2019-10-21;Max Planck Institute for the Physics of Complex Systems, Dresden, Germany;
# Fluid pumping and active flexoelectricity can promote lumen nucleation in cell assemblies;Poster;poster-8;Organoids : Modelling Organ Development and Disease in 3D Culture;2020-10-21;online conference;
# Hydraulic and electric control of cell spheroids;Poster;poster-9;EMBO Workshop Physics of living systems: From molecules to tissues;2021-06-07;online conference;
# Hydraulic and electric control of cell spheroids;Poster;poster-10;Physics Meets Biology;2021-07-26;online conference;

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
# conv = {'publi_id': lambda x: str(x), 'page': lambda x: str(x), 'arxiv_id': lambda x: str(x)}
conv = {}
talks = pd.read_csv("talks.csv", sep=";", header=0, converters=conv)#, engine ='python')
talks
# Out:
#                                                 title              type  \
# 0   Dynamical phase transition in assemblies of ch...      Invited Talk
# 1   Fluid pumping and flexoelectricity can drive l...      Invited Talk
# 2   Genuine (response-field) Langevin equations fo...  Contributed talk
# 3   Langevin equations for reaction-diffusion proc...  Contributed talk
# 4   Frequency regulators for the nonperturbative r...  Contributed talk
# 5   Fluid pumping can drive lumen nucleation and t...  Contributed talk
# 6    Hydraulic and electric control of cell spheroids  Contributed talk
# 7    Hydraulic and electric control of cell spheroids  Contributed talk
# 8             Nonlinear rheology of cellular networks  Contributed talk
# 9   Hydraulic and electric control of a cell spheroid  Contributed talk
# 10  Nonequilibrium critical phenomena: exact Lange...           Seminar
# 11           Collective dynamics of chemotactic cells           Seminar
# 12           Collective dynamics of chemotactic cells           Seminar
# 13           Collective dynamics of chemotactic cells           Seminar
# 14  Quorum effects in assemblies of chemotactic cells           Seminar
# 15  Polarization mechanism for chemotaxis and exac...           Seminar
# 16  Fluid pumping, lumen nucleation and electro-hy...           Seminar
# 17  Fluid pumping, lumen nucleation and electro-hy...           Seminar
# 18  Active mechanical and electrohydraulic propert...           Seminar
# 19  Active mechanical and electrohydraulic propert...           Seminar
# 20  Active mechanical and electrohydraulic propert...           Seminar
# 21  Active mechanical and electrohydraulic propert...           Seminar
# 22  Renormalization group approach to the collecti...           Seminar
# 23  Hysteresis, phase transitions and dangerous tr...            Poster
# 24  Langevin equations for reaction-diffusion proc...            Poster
# 25  Langevin equations for reaction-diffusion proc...            Poster
# 26  Fluid pumping and active flexoelectricity can ...            Poster
# 27  Fluid pumping and active flexoelectricity can ...            Poster
# 28  Fluid pumping and active flexoelectricity can ...            Poster
# 29  Fluid pumping and active flexoelectricity can ...            Poster
# 30  Fluid pumping and active flexoelectricity can ...            Poster
# 31   Hydraulic and electric control of cell spheroids            Poster
# 32   Hydraulic and electric control of cell spheroids            Poster
#
#       url_slug                                              venue        date  \
# 0   inv-talk-1  DPG Spring Meeting, Focus Session on Stochasti...  2019-04-04
# 1   inv-talk-2              Labex "Who am I?" 2022 annual meeting  2022-12-12
# 2       talk-1                   Journées de Physique Statistique  2016-01-28
# 3       talk-2                                 DPG Spring Meeting  2018-03-12
# 4       talk-3              Exact Renormalization Group (ERG2018)  2018-07-10
# 5       talk-4                                     Circle Meeting  2019-03-27
# 6       talk-5                          Virtual APS March Meeting  2021-03-16
# 7       talk-6                         Virtual DPG Spring Meeting  2021-03-23
# 8       talk-7                    Physical Biology Circle Meeting  2021-09-15
# 9       talk-8                     New frontiers in liquid matter  2022-07-07
# 10   seminar-1  Max Planck Institute for the Physics of Comple...  2017-03-30
# 11   seminar-2                            Laboratoire de Physique  2020-01-07
# 12   seminar-3         Laboratoire Interdisciplinaire de Physique  2020-01-09
# 13   seminar-4          Laboratoire Matière et Systèmes Complexes  2020-01-15
# 14   seminar-5  Laboratoire de Physique Théorique et Modèles S...  2020-03-31
# 15   seminar-6      Centre de Physique Théorique (online seminar)  2020-10-14
# 16   seminar-7  Laboratoire Interdisciplinaire de Physique (on...  2020-11-02
# 17   seminar-8           Laboratoire Jean Perrin (online seminar)  2020-11-10
# 18   seminar-9          Laboratoire Matière et Systèmes Complexes  2021-12-13
# 19  seminar-10                   Laboratoire Physico-Chimie Curie  2022-01-28
# 20  seminar-11  Laboratoire Physique et Mécanique des Milieux ...  2022-02-16
# 21  seminar-12                           Laboratoire Jean Perrin   2022-02-22
# 22  seminar-13  Laboratoire de Physique Théorique de la Matièr...  2022-10-10
# 23    poster-1            Optimization and Control of Smart Grids  2012-05-21
# 24    poster-2                             Beg Rohu summer school  2016-08-01
# 25    poster-3  42nd Conference of the Middle European Coopera...  2017-02-09
# 26    poster-4                          Les Houches summer school  2018-08-01
# 27    poster-5    Key Challenges in Statistical Physics (MECO 44)  2019-05-01
# 28    poster-6                   Mechanical Forces in Development  2019-07-03
# 29    poster-7                              Fluid Physics of Life  2019-10-21
# 30    poster-8  Organoids : Modelling Organ Development and Di...  2020-10-21
# 31    poster-9  EMBO Workshop Physics of living systems: From ...  2021-06-07
# 32   poster-10                              Physics Meets Biology  2021-07-26
#
#                                              location  description
# 0        Regensburg Universität,  Regensburg, Germany          NaN
# 1                                 ENSA, Paris, France          NaN
# 2                                ESPCI, Paris, France          NaN
# 3      Technische Universität Berlin, Berlin, Germany          NaN
# 4                  Sorbonne Université, Paris, France          NaN
# 5          Saarland Universität, Saarbrücken, Germany          NaN
# 6                                   online conference          NaN
# 7                                   online conference          NaN
# 8   Max Planck Institute for the Physics of Comple...          NaN
# 9                  Sorbonne Université, Paris, France          NaN
# 10                                   Dresden, Germany          NaN
# 11     École Normale Supérieure de Lyon, Lyon, France          NaN
# 12        Université Grenoble-Alpes, Grenoble, France          NaN
# 13                 Université de Paris, Paris, France          NaN
# 14              Université Paris-Orsay, Orsay, France          NaN
# 15        Aix-Marseille Université, Marseille, France          NaN
# 16        Université Grenoble-Alpes, Grenoble, France          NaN
# 17                Sorbonne Université, Paris, France           NaN
# 18                 Université de Paris, Paris, France          NaN
# 19                      Institut Curie, Paris, France          NaN
# 20                               ESPCI, Paris, France          NaN
# 21                Sorbonne Université, Paris, France           NaN
# 22                Sorbonne Université, Paris, France           NaN
# 23                          Santa Fe, New Mexico, USA          NaN
# 24                                   Beg Rohu, France          NaN
# 25     École Normale Supérieure de Lyon, Lyon, France          NaN
# 26                                Les Houches, France          NaN
# 27                     Kloster Seeon, Munich, Germany          NaN
# 28                          EMBL, Heidelberg, Germany          NaN
# 29  Max Planck Institute for the Physics of Comple...          NaN
# 30                                  online conference          NaN
# 31                                  online conference          NaN
# 32                                  online conference          NaN

# %%
# talks = pd.read_csv("talks.tsv", sep="\t", header=0)
# talks

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    if type(text) is str:
        return "".join(html_escape_table.get(c,c) for c in text)
    else:
        return "False"

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
loc_dict = {}

for row, item in talks.iterrows():
    print(item.type)
# Out:
# Invited Talk
# Invited Talk
# Contributed talk
# Contributed talk
# Contributed talk
# Contributed talk
# Contributed talk
# Contributed talk
# Contributed talk
# Contributed talk
# Seminar
# Seminar
# Seminar
# Seminar
# Seminar
# Seminar
# Seminar
# Seminar
# Seminar
# Seminar
# Seminar
# Seminar
# Seminar
# Poster
# Poster
# Poster
# Poster
# Poster
# Poster
# Poster
# Poster
# Poster
# Poster

# %%
loc_dict = {}

for row, item in talks.iterrows():
    
    md_filename = str(item.date) + "-" + item.url_slug + ".md"
    html_filename = str(item.date) + "-" + item.url_slug 
    year = item.date[:4]
    
    md = "---\ntitle: \""   + item.title + '"\n'
    md += "collection: talks" + "\n"
    
    if len(str(item.type)) > 3:
        md += 'type: "' + item.type + '"\n'
    else:
        md += 'type: "Talk"\n'
    
    md += "permalink: /talks/" + html_filename + "\n"
    
    if len(str(item.venue)) > 3:
        md += 'venue: "' + item.venue + '"\n'
        
    if len(str(item.location)) > 3:
        md += "date: " + str(item.date) + "\n"
    
    if len(str(item.location)) > 3:
        md += 'location: "' + str(item.location) + '"\n'
           
    md += "---\n"
    
    
#     if len(str(item.talk_url)) > 3:
#         md += "\n[More information here](" + item.talk_url + ")\n" 
        
    
    if len(str(item.description)) > 3:
        md += "\n" + html_escape(item.description) + "\n"
        
        
    md_filename = os.path.basename(md_filename)
    #print(md)
    
    with open("../_talks/" + md_filename, 'w') as f:
        f.write(md)

# %% [markdown]
# These files are in the talks directory, one directory below where we're working from.

# %%
# !ls ../_talks
# Out:
# 2012-05-21-poster-1.md   2019-10-21-poster-7.md   2021-06-07-poster-9.md
# 2016-01-28-talk-1.md     2020-01-07-seminar-2.md  2021-07-26-poster-10.md
# 2016-08-01-poster-2.md   2020-01-09-seminar-3.md  2021-09-15-talk-7.md
# 2017-02-09-poster-3.md   2020-01-15-seminar-4.md  2021-09-15-talk-8.md
# 2017-03-30-seminar-1.md  2020-03-31-seminar-5.md  2021-12-13-seminar-9.md
# 2018-03-12-talk-2.md     2020-10-14-seminar-6.md  2022-01-28-seminar-10.md
# 2018-07-10-talk-3.md     2020-10-21-poster-8.md   2022-02-16-seminar-11.md
# 2018-08-01-poster-4.md   2020-11-02-seminar-7.md  2022-02-22-seminar-12.md
# 2019-03-27-talk-4.md     2020-11-10-seminar-8.md  2022-07-07-talk-8.md
# 2019-04-04-inv-talk-1.md 2021-03-16-talk-5.md     2022-10-10-seminar-13.md
# 2019-04-04-talk-5.md     2021-03-16-talk-6.md     2022-12-12-inv-talk-2.md
# 2019-05-01-poster-5.md   2021-03-23-talk-6.md     talkmap.ipynb
# 2019-07-03-poster-6.md   2021-03-23-talk-7.md

# %%
# !cat ../_talks/2016-01-28-talk-1.md
# Out:
# ---
# title: "Genuine (response-field) Langevin equations for reaction-diffusion processes "
# collection: talks
# type: "Contributed talk"
# permalink: /talks/2016-01-28-talk-1
# venue: "Journées de Physique Statistique"
# date: 2016-01-28
# location: "ESPCI, Paris, France"
# ---

# %%
# !cat ../_talks/2019-04-04-inv-talk-1.md
# Out:
# ---
# title: "Dynamical phase transition in assemblies of chemotactic cells"
# collection: talks
# type: "Invited Talk"
# permalink: /talks/2019-04-04-inv-talk-1
# venue: "DPG Spring Meeting, Focus Session on Stochastic processes in biology"
# date: 2019-04-04
# location: "Regensburg Universität,  Regensburg, Germany"
# ---
